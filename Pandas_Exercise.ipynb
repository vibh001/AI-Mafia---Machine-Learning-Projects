# %% [markdown]
# # <center>Introduction to Pandas</center>
#
# ![](https://pandas.pydata.org/_static/pandas_logo.png)
#
#
# ## Installation
#
# Simply,
# ```
# pip install pandas
# ```
#
#
# ## Reading data from a CSV file
#
# You can read data from a CSV file using the ``read_csv`` function. By default, it assumes that the fields are comma-separated.

# %%
# import pandas
import pandas as pd

# %% [markdown]
# >The `imdb.csv` dataset contains Highest Rated IMDb "Top 1000" Titles.

# %%
# load imdb dataset as pandas dataframe
imdb_df=pd.read_csv('imdb_1000.csv')
imdb_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre  duration  \
# 0                R      Crime       142
# 1                R      Crime       175
# 2                R      Crime       200
# ...

# %%
# show first 5 rows of imdb_df
imdb_df.head()
# Out:
#    star_rating                     title content_rating   genre  duration  \
# 0          9.3  The Shawshank Redemption              R   Crime       142
# 1          9.2             The Godfather              R   Crime       175
# 2          9.1    The Godfather: Part II              R   Crime       200
# 3          9.0           The Dark Knight          PG-13  Action       152
# 4          8.9              Pulp Fiction              R   Crime       154
#
#                                          actors_list
# 0  [u'Tim Robbins', u'Morgan Freeman', u'Bob Gunt...
# 1    [u'Marlon Brando', u'Al Pacino', u'James Caan']
# 2  [u'Al Pacino', u'Robert De Niro', u'Robert Duv...
# 3  [u'Christian Bale', u'Heath Ledger', u'Aaron E...
# 4  [u'John Travolta', u'Uma Thurman', u'Samuel L....

# %% [markdown]
# >The `bikes.csv` dataset contains information about the number of bicycles that used certain bicycle lanes in Montreal in the year 2012.

# %%
# load bikes dataset as pandas dataframe
bikes_df=pd.read_csv('bikes.csv')
bikes_df
# Out:
#                                              Date Rachel / Papineau  Berri1  \
# 0                                      01-01-2012             00:00    16.0
# 1      02/01/2012;00:00;43;83;153;68;11;53;6;1;21             00:00     NaN
# 2     03/01/2012;00:00;58;135;248;104;2;89;3;2;15             00:00     NaN
# 3    04/01/2012;00:00;61;144;318;116;2;111;8;1;19             00:00     NaN
# 4    05/01/2012;00:00;95;197;330;124;6;97;13;2;16             00:00     NaN
# ..                                            ...               ...     ...
# 361             27/12/2012;00:00;8;12;7;4;;1;2;0;             00:00     NaN
# 362            28/12/2012;00:00;0;35;3;38;;0;0;0;             00:00     NaN
# 363                                    29-12-2012             00:00     0.0
# 364                                    30-12-2012             00:00     0.0
# 365                                    31-12-2012             00:00     0.0
#
# ...

# %%
# show first 3 rows of bikes_df
bikes_df[:3]
# Out:
#                                           Date Rachel / Papineau  Berri1  \
# 0                                   01-01-2012             00:00    16.0
# 1   02/01/2012;00:00;43;83;153;68;11;53;6;1;21             00:00     NaN
# 2  03/01/2012;00:00;58;135;248;104;2;89;3;2;15             00:00     NaN
#
#    Maisonneuve_2  Maisonneuve_1  Brébeuf  Parc  PierDup  \
# 0           35.0           51.0     38.0   5.0     26.0
# 1            NaN            NaN      NaN   NaN      NaN
# 2            NaN            NaN      NaN   NaN      NaN
#
#    CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier  Unnamed: 10
# 0                         10.0                   0.0         27.0
# 1                          NaN                   NaN          NaN
# 2                          NaN                   NaN          NaN

# %% [markdown]
# ## Selecting columns
#
# When you read a CSV, you get a kind of object called a DataFrame, which is made up of rows and columns. You get columns out of a DataFrame the same way you get elements out of a dictionary.

# %%
# list columns of imdb_df
imdb_df.columns
# Out:
# Index(['star_rating', 'title', 'content_rating', 'genre', 'duration',
#        'actors_list'],
#       dtype='object')

# %%
# what are the datatypes of values in columns
imdb_df.dtypes
# Out:
# star_rating       float64
# title              object
# content_rating     object
# genre              object
# duration            int64
# actors_list        object
# dtype: object

# %%
# list first 5 movie titles
imdb_df['title'].head()
# Out:
# 0    The Shawshank Redemption
# 1               The Godfather
# 2      The Godfather: Part II
# 3             The Dark Knight
# 4                Pulp Fiction
# Name: title, dtype: object

# %%
# show only movie title and genre
imdb_df[['title','genre']]
# Out:
#                                                title      genre
# 0                           The Shawshank Redemption      Crime
# 1                                      The Godfather      Crime
# 2                             The Godfather: Part II      Crime
# 3                                    The Dark Knight     Action
# 4                                       Pulp Fiction      Crime
# ..                                               ...        ...
# 974                                          Tootsie     Comedy
# 975                      Back to the Future Part III  Adventure
# 976  Master and Commander: The Far Side of the World     Action
# 977                                      Poltergeist     Horror
# 978                                      Wall Street      Crime
#
# [979 rows x 2 columns]

# %% [markdown]
# ## Understanding columns
#
# On the inside, the type of a column is ``pd.Series`` and pandas Series are internally numpy arrays. If you add ``.values`` to the end of any Series, you'll get its internal **numpy array**.

# %%
# show the type of duration column
type(imdb_df['duration'])
# Out:
# pandas.core.series.Series

# %%
# show duration values of movies as numpy arrays
import numpy as np
a=imdb_df['duration']
print(np.array(a))
# Out:
# [142 175 200 152 154  96 161 201 195 139 178 148 124 142 179 169 133 207
#  146 121 136 130 130 106 127 116 175 118 110  87 125 112 102 107 119  87
#  169 115 112 109 189 110 150 165 155 137 113 165  95 151 155 153 125 130
#  116  89 137 117  88 165 170  89 146  99  98 116 156 122 149 134 122 136
#  157 123 119 137 128 120 229 107 134 103 177 129 102 216 136  93  68 189
#   99 108 113 181 103 138 110 129  88 160 126  91 116 125 143  93 102 132
#  153 183 160 120 138 140 153 170 129  81 127 131 172 115 108 107 129 156
#   96  91  95 162 130  86 186 151  96 170 118 161 131 126 131 129 224 180
#  105 117 140 119 124 130 139 107 132 117 126 122 178 238 149 172  98 116
#  116 123 148 123 182  92  93 100 135 105  94 140  83  95  98 143  99  98
#  121 163 121 167 188 121 109 110 129 127  94 107 100 117 129 120 121 133
#  111 122 101 134 165 138 212 154  89 134  93 114  88 130 101 158  99 108
#  124 132 113 131 191 167 130 147 102  88 165 132 118 101 108 174  98  92
# ...

# %% [markdown]
# ## Applying functions to columns
#
# Use `.apply` function to apply any function to each element of a column.

# %%
# convert all the movie titles to uppercase
to_uppercase = lambda x: x.upper()
imdb_df['title'].apply(to_uppercase).head()
# Out:
# 0    THE SHAWSHANK REDEMPTION
# 1               THE GODFATHER
# 2      THE GODFATHER: PART II
# 3             THE DARK KNIGHT
# 4                PULP FICTION
# Name: title, dtype: object

# %% [markdown]
# ## Plotting a column
#
# Use ``.plot()`` function!

# %%
# plot the bikers travelling to Berri1 over the year
import matplotlib.pyplot as plt
bikes_df['Berri1'].plot()
plt.show()

# %%
# plot all the columns of bikes_df
bikes_df.plot()
plt.legend()
plt.show()

# %% [markdown]
# ## Value counts
#
# Get count of unique values in a particular column/Series.

# %%
# what are the unique genre in imdb_df?
c=imdb_df['genre'].value_counts()
c
# Out:
# Drama        278
# Comedy       156
# Action       136
# Crime        124
# Biography     77
# Adventure     75
# Animation     62
# Horror        29
# Mystery       16
# Western        9
# Thriller       5
# Sci-Fi         5
# Film-Noir      3
# Family         2
# Fantasy        1
# History        1
# Name: genre, dtype: int64

# %%
# plotting value counts of unique genres as a bar chart
c.plot.bar()

# %%
# plotting value counts of unique genres as a pie chart
c.plot.pie()

# %% [markdown]
# ## Index
#
# ### DATAFRAME = COLUMNS + INDEX + ND DATA
#
# ### SERIES = INDEX + 1-D DATA
#
# **Index** or (**row labels**) is one of the fundamental data structure of pandas. It can be thought of as an **immutable array** and an **ordered set**.
#
# > Every row is uniquely identified by its index value.

# %%
# show index of bikes_df
bikes_df[index]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-71-e1d8f192f9f6> in <module>
#       1 # show index of bikes_df
# ----> 2 bikes_df[index]
#
# NameError: name 'index' is not defined

# %%
# get row for date 2012-01-01
bikes_df[bikes_df['Date'].values=='01-01-2012']
# Out:
#          Date Rachel / Papineau  Berri1  Maisonneuve_2  Maisonneuve_1  \
# 0  01-01-2012             00:00    16.0           35.0           51.0
#
#    Brébeuf  Parc  PierDup  CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier  \
# 0     38.0   5.0     26.0                         10.0                   0.0
#
#    Unnamed: 10
# 0         27.0

# %% [markdown]
# #### To get row by integer index:
#
# Use ``.iloc[]`` for purely integer-location based indexing for selection by position.

# %%
# show 11th row of imdb_df using iloc
imdb_df.iloc[11]
# Out:
# star_rating                                                     8.8
# title                                                     Inception
# content_rating                                                PG-13
# genre                                                        Action
# duration                                                        148
# actors_list       [u'Leonardo DiCaprio', u'Joseph Gordon-Levitt'...
# Name: 11, dtype: object

# %% [markdown]
# ## Selecting rows where column has a particular value

# %%
# select only those movies where genre is adventure
imdb_df[imdb_df['genre'].values=='Adventure']
# Out:
#      star_rating                                              title  \
# 7            8.9      The Lord of the Rings: The Return of the King
# 10           8.8  The Lord of the Rings: The Fellowship of the Ring
# 14           8.8              The Lord of the Rings: The Two Towers
# 15           8.7                                       Interstellar
# 54           8.5                                 Back to the Future
# ..           ...                                                ...
# 936          7.4                                          True Grit
# 937          7.4                                          Labyrinth
# 943          7.4                                    The Bucket List
# 953          7.4                              The NeverEnding Story
# 975          7.4                        Back to the Future Part III
#
#     content_rating      genre  duration  \
# 7            PG-13  Adventure       201
# 10           PG-13  Adventure       178
# ...

# %%
# which genre has highest number of movies with star rating above 8 and duration more than 130 minutes?
d=imdb_df[np.logical_and(imdb_df['star_rating']>=8, imdb_df['duration']>130)].genre.value_counts()
print(d.keys()[0])
# Out:
# Drama

# %% [markdown]
# ## Adding a new column to DataFrame

# %%
# add a weekday column to bikes_df
weekday=['Sunday' for i in range (bikes_df.shape[0])]
bikes_df['weekday']=weekday
bikes_df
# Out:
#   File "<ipython-input-167-2d63cb9e8f25>", line 3
#     weekday=['Sunday','Monday','Wednesday','Saturday','Sunday','Friday' for i in range (n)]
#                                                                           ^
# SyntaxError: invalid syntax

# %% [markdown]
# ## Deleting an existing column from DataFrame

# %%
# remove column 'Unnamed: 1' from bikes_df
bikes_df.drop('Maisonneuve_2',axis=1)
# Out:
#                                              Date Rachel / Papineau  Berri1  \
# 0                                      01-01-2012             00:00    16.0
# 1      02/01/2012;00:00;43;83;153;68;11;53;6;1;21             00:00     NaN
# 2     03/01/2012;00:00;58;135;248;104;2;89;3;2;15             00:00     NaN
# 3    04/01/2012;00:00;61;144;318;116;2;111;8;1;19             00:00     NaN
# 4    05/01/2012;00:00;95;197;330;124;6;97;13;2;16             00:00     NaN
# ..                                            ...               ...     ...
# 361             27/12/2012;00:00;8;12;7;4;;1;2;0;             00:00     NaN
# 362            28/12/2012;00:00;0;35;3;38;;0;0;0;             00:00     NaN
# 363                                    29-12-2012             00:00     0.0
# 364                                    30-12-2012             00:00     0.0
# 365                                    31-12-2012             00:00     0.0
#
# ...

# %% [markdown]
# ## Deleting a row in DataFrame

# %%
# remove row no. 1 from bikes_df
bikes_df.drop(index=0)
# Out:
#                                              Date Rachel / Papineau  Berri1  \
# 1      02/01/2012;00:00;43;83;153;68;11;53;6;1;21             00:00     NaN
# 2     03/01/2012;00:00;58;135;248;104;2;89;3;2;15             00:00     NaN
# 3    04/01/2012;00:00;61;144;318;116;2;111;8;1;19             00:00     NaN
# 4    05/01/2012;00:00;95;197;330;124;6;97;13;2;16             00:00     NaN
# 5      06/01/2012;00:00;75;146;244;98;4;86;4;0;17             00:00     NaN
# ..                                            ...               ...     ...
# 361             27/12/2012;00:00;8;12;7;4;;1;2;0;             00:00     NaN
# 362            28/12/2012;00:00;0;35;3;38;;0;0;0;             00:00     NaN
# 363                                    29-12-2012             00:00     0.0
# 364                                    30-12-2012             00:00     0.0
# 365                                    31-12-2012             00:00     0.0
#
# ...

# %% [markdown]
# ## Group By
#
# Any groupby operation involves one of the following operations on the original object. They are −
#
# - Splitting the Object
#
# - Applying a function
#
# - Combining the results
#
# In many situations, we split the data into sets and we apply some functionality on each subset. In the apply functionality, we can perform the following operations −
#
# - **Aggregation** − computing a summary statistic
#
# - **Transformation** − perform some group-specific operation
#
# - **Filtration** − discarding the data with some condition

# %%
# group imdb_df by movie genres
imdb_df.groupby('genre')

# %%
# get crime movies group
imdb_df.groupby(imdb_df['genre']=='Crime')

# %%
# get mean of movie durations for each group
import numpy as np
def mean(x):
    return np.mean(x)
c=imdb_df.groupby('genre').duration.apply(mean)
c
# Out:
# genre
# Action       126.485294
# Adventure    134.840000
# Animation     96.596774
# Biography    131.844156
# Comedy       107.602564
# Crime        122.298387
# Drama        126.539568
# Family       107.500000
# Fantasy      112.000000
# Film-Noir     97.333333
# History       66.000000
# Horror       102.517241
# Mystery      115.625000
# Sci-Fi       109.000000
# Thriller     114.200000
# Western      136.666667
# Name: duration, dtype: float64

# %%
# change duration of all movies in a particular genre to mean duration of the group
imdb_df.duration=imdb_df.groupby('genre').duration.transform(mean)
imdb_df
# Out:
#      star_rating                                            title  \
# 0            9.3                         The Shawshank Redemption
# 1            9.2                                    The Godfather
# 2            9.1                           The Godfather: Part II
# 3            9.0                                  The Dark Knight
# 4            8.9                                     Pulp Fiction
# ..           ...                                              ...
# 974          7.4                                          Tootsie
# 975          7.4                      Back to the Future Part III
# 976          7.4  Master and Commander: The Far Side of the World
# 977          7.4                                      Poltergeist
# 978          7.4                                      Wall Street
#
#     content_rating      genre    duration  \
# 0                R      Crime  122.298387
# 1                R      Crime  122.298387
# 2                R      Crime  122.298387
# ...

# %%
# drop groups/genres that do not have average movie duration greater than 120.
m=c.keys().tolist()
n=c.tolist()
for i in range(len(n)):
    if n[i]>120:
        print("{}     {}".format(m[i],n[i]))
# Out:
# Action     126.48529411764706
# Adventure     134.84
# Biography     131.84415584415584
# Crime     122.29838709677419
# Drama     126.53956834532374
# Western     136.66666666666666

# %%
# group weekday wise bikers count
c=bikes_df.groupby('weekday')
c

# %%
# get weekday wise biker count
def sum(x):
    return np.sum(x)
c.apply(sum)
# Out:
#                                                       Date  \
# weekday
# Sunday   01-01-201202/01/2012;00:00;43;83;153;68;11;53;...
#
#                                          Rachel / Papineau  Berri1  \
# weekday
# Sunday   00:0000:0000:0000:0000:0000:0000:0000:0000:000...    16.0
#
#          Maisonneuve_2  Maisonneuve_1  Brébeuf  Parc  PierDup  \
# weekday
# Sunday            71.0           63.0     93.0   5.0     53.0
#
#          CSC (Côte Sainte-Catherine)  Pont_Jacques_Cartier  Unnamed: 10  \
# weekday
# Sunday                          10.0                   0.0         27.0
#
#                                                    weekday
# weekday
# Sunday   SundaySundaySundaySundaySundaySundaySundaySund...

# %%
# plot weekday wise biker count for 'Berri1'
c.Berri1.plot()
# Out:
# weekday
# Sunday    AxesSubplot(0.125,0.125;0.775x0.755)
# Name: Berri1, dtype: object

# %% [markdown]
# ![](https://memegenerator.net/img/instances/500x/73988569/pythonpandas-is-easy-import-and-go.jpg)
